# %% [markdown]
# ### Python ile Mekansal Veri İşlemeye Giriş
#
# Kullanacağımız araçlar
#
# Anaconda https://www.anaconda.com/distribution/#windows Spyder Jupyter Notebook Github geopandas numpy
#
# Spyder bir bilimsel entegre geliştirme ortamıdır.
#
# Jupyter Notebook
#
# Numpy: NumPy, Python programlama dili için bir kütüphane olup, büyük, çok boyutlu diziler ve matrisler için destek eklerken, bu dizilerde çalışmak için yüksek düzeyli matematiksel işlevlerin geniş bir koleksiyonudur
#
# Pandas: Özellikle, sayısal tabloları ve zaman serilerini değiştirmek için veri yapıları ve işlemler sunar
#
# Matplotlib, Python programlama dili ve sayısal matematik uzantısı NumPy için bir çizim kütüphanesidir.

# %% [markdown]
# ## Kütüphanelerin Yüklenmesi

# %%
import pandas as pd
import geopandas
import matplotlib

# %%
iller = geopandas.read_file("zip://data/gadm36_TUR_1.zip")

# %%
iller.head()
# Out:
#   GID_0  NAME_0    GID_1    NAME_1       VARNAME_1 NL_NAME_1 TYPE_1 ENGTYPE_1  \
# 0   TUR  Turkey  TUR.1_1     Adana          Seyhan      None     Il  Province
# 1   TUR  Turkey  TUR.2_1  Adiyaman        Adıyaman      None     Il  Province
# 2   TUR  Turkey  TUR.3_1     Afyon  Afyonkarahisar      None     Il  Province
# 3   TUR  Turkey  TUR.4_1      Agri   Ağri|Karaköse      None     Il  Province
# 4   TUR  Turkey  TUR.5_1   Aksaray            None      None     Il  Province
#
#    CC_1 HASC_1                                           geometry
# 0  None  TR.AA  MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# 1  None  TR.AD  POLYGON ((38.68339 37.60323, 38.66182 37.59428...
# 2  None  TR.AF  POLYGON ((30.18261 37.90116, 30.18878 37.89117...
# 3  None  TR.AG  POLYGON ((43.71635 39.37020, 43.70746 39.36575...
# 4  None  TR.AK  POLYGON ((34.39513 38.19467, 34.39626 38.18270...

# %%
iller.geometry
# Out:
# 0     MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# 1     POLYGON ((38.68339 37.60323, 38.66182 37.59428...
# 2     POLYGON ((30.18261 37.90116, 30.18878 37.89117...
# 3     POLYGON ((43.71635 39.37020, 43.70746 39.36575...
# 4     POLYGON ((34.39513 38.19467, 34.39626 38.18270...
# 5     POLYGON ((35.22178 40.66905, 35.20362 40.66770...
# 6     POLYGON ((33.74255 39.11185, 33.76644 39.10598...
# 7     MULTIPOLYGON (((30.55347 36.46097, 30.55347 36...
# 8     POLYGON ((42.54808 40.64073, 42.53852 40.66104...
# 9     POLYGON ((41.94059 40.74382, 41.93707 40.73332...
# 10    MULTIPOLYGON (((27.32986 37.33125, 27.32986 37...
# 11    MULTIPOLYGON (((26.52958 39.32097, 26.52958 39...
# 12    MULTIPOLYGON (((32.49186 41.29233, 32.47286 41...
# 13    POLYGON ((41.65804 37.65389, 41.64595 37.64524...
# 14    POLYGON ((39.84372 39.97449, 39.83974 39.97258...
# 15    POLYGON ((29.79770 39.71835, 29.77377 39.72666...
# 16    POLYGON ((40.87106 38.59167, 40.84577 38.59095...
# 17    POLYGON ((42.54032 38.09015, 42.51196 38.10236...
# 18    POLYGON ((30.62383 40.33518, 30.63105 40.34195...
# 19    POLYGON ((29.68426 36.91900, 29.67694 36.93264...
# 20    MULTIPOLYGON (((28.53903 40.56708, 28.53903 40...
# 21    MULTIPOLYGON (((26.05347 39.84736, 26.05347 39...
# 22    POLYGON ((34.13117 40.49349, 34.13253 40.48812...
# 23    POLYGON ((35.34368 40.35833, 35.34592 40.34692...
# 24    POLYGON ((29.19095 36.88718, 29.18103 36.89913...
# 25    POLYGON ((39.57993 37.89192, 39.55878 37.90680...
# 26    POLYGON ((31.36094 40.66146, 31.31655 40.65717...
# 27    MULTIPOLYGON (((26.01097 40.78959, 26.01097 40...
# 28    POLYGON ((39.11914 38.33826, 39.10740 38.33697...
# 29    POLYGON ((39.98635 39.51869, 39.95698 39.52531...
#                             ...
# 51    MULTIPOLYGON (((30.26403 41.21764, 30.26403 41...
# 52    POLYGON ((34.51411 37.33314, 34.50755 37.32803...
# 53    POLYGON ((29.89437 38.70968, 29.89274 38.73051...
# 54    POLYGON ((37.73729 37.83413, 37.71812 37.83595...
# 55    POLYGON ((28.82543 38.35532, 28.84807 38.33792...
# 56    POLYGON ((40.85432 37.10750, 40.85352 37.10732...
# 57    MULTIPOLYGON (((33.82819 36.26931, 33.82819 36...
# 58    MULTIPOLYGON (((29.05986 36.54208, 29.05986 36...
# 59    POLYGON ((42.06134 38.71339, 42.05844 38.70570...
# 60    POLYGON ((34.59204 38.38596, 34.57722 38.38510...
# 61    POLYGON ((34.78333 37.39600, 34.71869 37.39649...
# 62    POLYGON ((38.15565 40.50869, 38.13857 40.49934...
# 63    POLYGON ((36.65104 37.32999, 36.66411 37.32239...
# 64    POLYGON ((40.48348 40.53534, 40.48349 40.60283...
# 65    MULTIPOLYGON (((30.36891 41.17931, 30.36930 41...
# 66    MULTIPOLYGON (((36.06104 40.84315, 36.05407 40...
# 67    POLYGON ((39.45037 36.69899, 39.43916 36.69527...
# 68    POLYGON ((41.87389 37.74025, 41.87281 37.75165...
# 69    POLYGON ((34.84486 41.19581, 34.81906 41.20172...
# 70    POLYGON ((42.45850 37.13239, 42.45372 37.12970...
# 71    POLYGON ((36.37404 39.15341, 36.35278 39.14428...
# 72    POLYGON ((27.16014 40.62236, 27.15986 40.62236...
# 73    POLYGON ((36.42102 39.95630, 36.33159 39.95610...
# 74    POLYGON ((39.77802 40.69231, 39.76629 40.67451...
# 75    POLYGON ((39.63027 38.80182, 39.62471 38.79961...
# 76    POLYGON ((29.57592 38.19177, 29.56290 38.19193...
# 77    POLYGON ((44.49154 38.30873, 44.49103 38.30837...
# 78    POLYGON ((29.03236 40.47859, 29.03236 40.47847...
# 79    POLYGON ((35.96196 39.91003, 35.96333 39.90491...
# 80    POLYGON ((31.49785 41.05423, 31.46466 41.05458...
# Name: geometry, Length: 81, dtype: geometry

# %%
iller.geometry[2]

# %%
iller.NAME_1[2]
# Out:
# 'Afyon'

# %%
iller.plot()

# %%
type(iller)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(iller.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
iller.geometry.area
# Out:
# 0     1.612729
# 1     0.759168
# 2     1.525553
# 3     1.079759
# 4     0.786662
# 5     0.661862
# 6     2.707828
# 7     2.137219
# 8     0.513205
# 9     0.832857
# 10    0.818538
# 11    1.544658
# 12    0.278955
# 13    0.445755
# 14    0.358921
# 15    0.490831
# 16    0.846329
# 17    0.895701
# 18    0.879853
# 19    0.738516
# 20    1.147608
# 21    1.032032
# 22    0.843826
# 23    1.309368
# 24    1.113572
# 25    1.522050
# 26    0.255224
# 27    0.658190
# 28    0.961281
# 29    1.211343
#         ...
# 51    0.431493
# 52    4.199797
# 53    1.273441
# 54    1.187491
# 55    1.370096
# 56    1.072012
# 57    1.534905
# 58    1.299520
# 59    0.845590
# 60    0.532896
# 61    0.736926
# 62    0.630761
# 63    0.312220
# 64    0.389279
# 65    0.501080
# 66    1.022311
# 67    1.992951
# 68    0.510686
# 69    0.649366
# 70    0.803267
# 71    2.971832
# 72    0.708731
# 73    1.043121
# 74    0.536912
# 75    0.839120
# 76    0.508203
# 77    2.179277
# 78    0.069144
# 79    1.380989
# 80    0.328679
# Length: 81, dtype: float64

# %%
iller.geometry.centroid
# Out:
# 0     POINT (35.59445 37.46170)
# 1     POINT (38.33526 37.80429)
# 2     POINT (30.65645 38.62266)
# 3     POINT (43.26693 39.57460)
# 4     POINT (33.84149 38.37142)
# 5     POINT (35.72044 40.69092)
# 6     POINT (32.61694 39.79575)
# 7     POINT (30.92108 36.79883)
# 8     POINT (42.76259 41.11671)
# 9     POINT (41.81543 41.10846)
# 10    POINT (28.01762 37.75268)
# 11    POINT (27.86486 39.67571)
# 12    POINT (32.46654 41.54825)
# 13    POINT (41.40834 38.00344)
# 14    POINT (40.22972 40.23521)
# 15    POINT (30.11845 40.11461)
# 16    POINT (40.72239 39.04520)
# 17    POINT (42.40159 38.55024)
# 18    POINT (31.66935 40.60176)
# 19    POINT (30.09131 37.42171)
# 20    POINT (29.02404 40.11434)
# 21    POINT (26.75106 40.05661)
# 22    POINT (33.42615 40.68986)
# 23    POINT (34.66202 40.56634)
# 24    POINT (29.26288 37.73451)
# 25    POINT (40.34673 38.13569)
# 26    POINT (31.26864 40.89399)
# 27    POINT (26.60450 41.24689)
# 28    POINT (39.42613 38.67723)
# 29    POINT (39.31753 39.66460)
#                 ...
# 51    POINT (29.89426 40.85826)
# 52    POINT (32.63967 38.03901)
# 53    POINT (29.58733 39.27229)
# 54    POINT (38.11794 38.51353)
# 55    POINT (28.14849 38.76452)
# 56    POINT (40.89936 37.36665)
# 57    POINT (33.82680 36.69199)
# 58    POINT (28.47079 37.02613)
# 59    POINT (41.88292 39.01410)
# 60    POINT (34.69136 38.81058)
# 61    POINT (34.73886 37.95327)
# 62    POINT (37.53635 40.78732)
# 63    POINT (36.24725 37.26662)
# 64    POINT (40.86805 40.93171)
# 65    POINT (30.53899 40.73980)
# 66    POINT (36.01568 41.21213)
# 67    POINT (39.10434 37.25088)
# 68    POINT (42.18300 37.94890)
# 69    POINT (34.88435 41.62183)
# 70    POINT (42.61468 37.50660)
# 71    POINT (37.31727 39.56897)
# 72    POINT (27.44490 41.11193)
# 73    POINT (36.60459 40.36584)
# LINESTRING (30.73027527777777 69.44805444444444, 30.72472555555555 69.4502786111111, 30.70444333333333 69.45055555555555, 30.68639083333333 69.44833361111111, 30.67055527777778 69.44527833333332, 30.65028027777778 69.44388944444444, 30.64657111111111 69.44411805555555, 30.62873611111111 69.44240388888888, 30.61545444444445 69.44099722222222, 30.59879166666667 69.44176944444445, 30.58702444444444 69.44314999999999, 30.56922722222222 69.44343611111111, 30.55567694444444 69.44208722222221, 30.53658333333333 69.43788277777777, 30.52578722222222 69.4357361111111, 30.50347055555556 69.43408444444444, 30.50000027777778 69.43423305555555, 30.48041777777777 69.43507194444443, 30.45336166666666 69.4368086111111, 30.43055333333333 69.43690916666667, 30.40560972222222 69.43559999999999, 30.37440222222222 69.43406944444445, 30.35823722222222 69.43305972222223, 30.3383125 69.43191805555554, 30.31250027777777 69.42923194444444, 30.28719833333333 69.42478166666666, 30.2650325 69.42266333333333, 30.25176083333333 69.4204125, 30.23348444444444 69.41798416666667, 30.22021805555556 69.41573138888889, 30.20820694444444 69.41352305555554, 30.19969888888889 69.41232916666665, 30.19732277777778 69.41179916666665)

# %% [markdown]
# ## Koordinat Sistemleri
#
# epsg.io'dan koordinat sistemlerini inceleyebilirsiniz

# %%
iller.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
iller_mercator = iller.to_crs(epsg=3395)

# %%
iller_mercator.plot()

# %%
iller.plot()

# %% [markdown]
# ## Veri Görselleştirme

# %%
ax = iller.plot()

# %%
ax = iller.plot(edgecolor='k', facecolor='none')

# %%
ax = iller.plot(edgecolor='k', facecolor='none', figsize=(15,10))

# %% [markdown]
# ## Katmanları üst üste görselleştirme

# %%
ax = iller.plot(edgecolor='k', facecolor='none', figsize=(15,10))

nehirler.plot(ax=ax)
ax.set(xlim=(25,45), ylim=(35,43))
havalimanlari.plot(ax=ax)

# %% [markdown]
# ## Mekansal İlişkiler ve Operasyonlar

# %%
import pandas as pd
import geopandas

# %%
havalimanlari = geopandas.read_file("zip://./data/ne_10m_airports.zip")
sehirler = geopandas.read_file("zip://./data/ne_10m_populated_places.zip")
tren = geopandas.read_file("zip://./data/ne_10m_railroads.zip")
nehirler = geopandas.read_file("zip://./data/ne_10m_rivers_lake_centerlines.zip")
iller = geopandas.read_file("zip://./data/gadm36_TUR_1.zip")

# %%
sehirler.head()
# Out:
#    SCALERANK  NATSCALE  LABELRANK       FEATURECLA                    NAME  \
# 0         10         1          8  Admin-1 capital  Colonia del Sacramento
# 1         10         1          8  Admin-1 capital                Trinidad
# 2         10         1          8  Admin-1 capital             Fray Bentos
# 3         10         1          8  Admin-1 capital               Canelones
# 4         10         1          8  Admin-1 capital                 Florida
#
#   NAMEPAR NAMEALT  DIFFASCII               NAMEASCII  ADM0CAP  ...  \
# 0    None    None          0  Colonia del Sacramento      0.0  ...
# 1    None    None          0                Trinidad      0.0  ...
# 2    None    None          0             Fray Bentos      0.0  ...
# 3    None    None          0               Canelones      0.0  ...
# 4    None    None          0                 Florida      0.0  ...
#
#           name_ja     name_ko                 name_nl                 name_pl  \
# 0  コロニア・デル・サクラメント  콜로니아델사크라멘토  Colonia del Sacramento  Colonia del Sacramento
# 1            トリニダ       트리니다드                Trinidad                Trinidad
# 2        フライ・ベントス      프라이벤토스             Fray Bentos             Fray Bentos
# 3          カネローネス       카넬로네스               Canelones               Canelones
# 4            フロリダ        플로리다                 Florida                 Florida
#
#                   name_sv                 name_tr                 name_vi  \
# 0  Colonia del Sacramento  Colonia del Sacramento  Colonia del Sacramento
# 1                Trinidad                Trinidad                Trinidad
# 2             Fray Bentos             Fray Bentos             Fray Bentos
# 3               Canelones               Canelones               Canelones
# 4                 Florida                 Flordia                 Florida
#
#   wdid_score       ne_id                     geometry
# 0          4  1159112629  POINT (-57.84000 -34.48000)
# 1          4  1159112647  POINT (-56.90100 -33.54400)
# 2          4  1159112663  POINT (-58.30400 -33.13900)
# 3          4  1159112679  POINT (-56.28400 -34.53800)
# 4          4  1159112703  POINT (-56.21500 -34.09900)
#
# [5 rows x 120 columns]

# %%
ankara = iller.loc[iller['NAME_1'] == 'Ankara', 'geometry'].squeeze()

ankaraC = sehirler.loc[sehirler['NAME'] == 'Ankara', 'geometry'].squeeze()
istanbulC = sehirler.loc[sehirler['NAME'] == 'Istanbul', 'geometry'].squeeze()

# %%
ankaraC
istanbulC

# %%
# ankara ve istanbul arasinda cizgi veri olusturma
from shapely.geometry import LineString

# %%
line = LineString([ankaraC, istanbulC])

# %%
line

# %%
geopandas.GeoSeries([ankaraC, istanbulC, ankara, line])
# Out:
# 0                            POINT (32.86245 39.92918)
# 1                            POINT (29.00806 41.10694)
# 2    POLYGON ((33.74255 39.11185, 33.76644 39.10598...
# 3    LINESTRING (32.86245 39.92918, 29.00806 41.10694)
# dtype: geometry

# %%
geopandas.GeoSeries([ankaraC, istanbulC, ankara, line]).plot(cmap='Accent')

# %%
ankaraC.within(ankara)
# Out:
# True

# %%
ankara.contains(ankaraC)
# Out:
# True

# %%
ankara.contains(istanbulC)
# Out:
# False

# %%
ankara.contains(line)
# Out:
# False

# %%
ankara.intersects(line)
# Out:
# True

# %%
iller.contains(istanbulC)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Length: 81, dtype: bool

# %%
 iller[iller.contains(istanbulC)]
# Out:
#    GID_0  NAME_0     GID_1    NAME_1  \
# 39   TUR  Turkey  TUR.40_1  Istanbul
#
#                                             VARNAME_1 NL_NAME_1 TYPE_1  \
# 39  İstanbul|Constantinople|Estambul|Istambul|Kons...      None     Il
#
#    ENGTYPE_1  CC_1 HASC_1                                           geometry
# 39  Province  None  TR.IB  MULTIPOLYGON (((29.11403 40.82069, 29.11403 40...

# %%
 iller[iller.contains(istanbulC)].plot()

# %%
nehirler.head()
# Out:
#               dissolve  scalerank       featurecla             name name_alt  \
# 0               0River        1.0            River  Irrawaddy Delta     None
# 1  1001Lake Centerline        9.0  Lake Centerline        Tonle Sap     None
# 2            1001River        9.0            River        Tonle Sap     None
# 3  1002Lake Centerline        9.0  Lake Centerline          Sheksna     None
# 4            1002River        9.0            River          Sheksna     None
#
#    rivernum  note  min_zoom    name_en  min_label  ...    name_pl  \
# 0         0  None       2.0  Irrawaddy        3.0  ...    Irawadi
# 1      1001  None       7.1       None        8.1  ...  Tonle Sap
# 2      1001  None       7.1       None        8.1  ...  Tonle Sap
# 3      1002  None       7.1    Sheksna        8.1  ...    Szeksna
# 4      1002  None       7.1    Sheksna        8.1  ...    Szeksna
#
#        name_pt   name_ru    name_sv        name_tr           name_vi name_zh  \
# 0  Rio Irauádi   Иравади  Irrawaddy  İravadi Nehri  Sông Ayeyarwaddy   伊洛瓦底江
# 1         None  Тонлесап       None           None              None    None
# 2         None  Тонлесап       None           None              None    None
# 3         None    Шексна    Sjeksna           None              None   舍克斯納河
# 4         None    Шексна    Sjeksna           None              None   舍克斯納河
#
#   wdid_score       ne_id                                           geometry
# 0          2  1159109417  MULTILINESTRING ((95.45110 17.82050, 95.42766 ...
# 1          4  1159109429  MULTILINESTRING ((103.68743 13.22468, 103.7133...
# 2          4  1159109445  LINESTRING (104.61476 12.38203, 104.61769 12.3...
# 3          4  1159109447  LINESTRING (37.73951 59.07954, 37.75733 59.103...
# 4          4  1159109461  LINESTRING (38.47804 59.21666, 38.48528 59.228...
#
# [5 rows x 35 columns]

# %%
dicle = nehirler[nehirler['name'] == 'Dicle'].geometry.squeeze()

# %%
dicle

# %%
iller[iller.crosses(dicle)]
# Out:
#    GID_0  NAME_0     GID_1      NAME_1   VARNAME_1 NL_NAME_1 TYPE_1 ENGTYPE_1  \
# 13   TUR  Turkey  TUR.14_1      Batman        None      None     Il  Province
# 25   TUR  Turkey  TUR.26_1  Diyarbakir  Diyarbakır      None     Il  Province
# 28   TUR  Turkey  TUR.29_1      Elazığ      Elazig      None     Il  Province
# 56   TUR  Turkey  TUR.57_1      Mardin        None      None     Il  Province
# 68   TUR  Turkey  TUR.69_1       Siirt        None      None     Il  Province
# 70   TUR  Turkey  TUR.71_1      Sirnak      Şırnak      None     Il  Province
#
#     CC_1 HASC_1                                           geometry
# 13  None  TR.BM  POLYGON ((41.65804 37.65389, 41.64595 37.64524...
# 25  None  TR.DY  POLYGON ((39.57993 37.89192, 39.55878 37.90680...
# 28  None  TR.EG  POLYGON ((39.11914 38.33826, 39.10740 38.33697...
# 56  None  TR.MR  POLYGON ((40.85432 37.10750, 40.85352 37.10732...
# 68  None  TR.SI  POLYGON ((41.87389 37.74025, 41.87281 37.75165...
# 70  None  TR.SR  POLYGON ((42.45850 37.13239, 42.45372 37.12970...

# %%
iller[iller.crosses(dicle)].plot()

# %%
iller[iller.intersects(dicle)].plot()

# %% [markdown]
# ## Mekansal Operasyonlar

# %%
anitkabir = ankara.centroid

# %%
print(anitkabir)
# Out:
# POINT (32.61693629826807 39.79575415554407)

# %%
dicleBBOX = dicle.minimum_rotated_rectangle

# %%
dicleBBOX

# %%
geopandas.GeoSeries([ankara, anitkabir.buffer(0.5)]).plot(alpha= 0.5, cmap='Accent')

# %%
anitkabir.buffer(0.5).intersection(ankara)

# %%
anitkabir.buffer(1).union(ankara)

# %%
anitkabir.buffer(1).difference(ankara)

# %% [markdown]
# ## Mekansal Birleşimler

# %%
havalimanlari = geopandas.read_file("zip://./data/ne_10m_airports.zip")
sehirler = geopandas.read_file("zip://./data/ne_10m_populated_places.zip")
tren = geopandas.read_file("zip://./data/ne_10m_railroads.zip")
nehirler = geopandas.read_file("zip://./data/ne_10m_rivers_lake_centerlines.zip")
iller = geopandas.read_file("zip://./data/tr_iller/gadm36_TUR_1.zip")
ulkeler = geopandas.read_file("zip://./data/ne_110m_admin_0_countries.zip")

iller.head()
# Out:
#      NAME_1          alan                                           geometry
# 0     Adana  1.583493e+10  MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# 1  Adiyaman  7.420537e+09  POLYGON ((38.68339 37.60323, 38.66182 37.59428...
# 2     Afyon  1.474743e+10  POLYGON ((30.18261 37.90116, 30.18878 37.89117...
# 3      Agri  1.030035e+10  POLYGON ((43.71635 39.37020, 43.70746 39.36575...
# 4   Aksaray  7.630818e+09  POLYGON ((34.39513 38.19467, 34.39626 38.18270...

# %%
import pandas as pd

# %%
df = pd.read_excel('./data/veriseti.xlsx')

# %%
print(df.columns)
# Out:
# Index(['NAME_1', 'ToplamCocuk', 'ToplamKorucuyuAile'], dtype='object')

# %%
iller2 = iller.merge(df, on='NAME_1')

# %%
iller2.head(10)
# Out:
#      NAME_1          alan                                           geometry  \
# 0     Adana  1.583493e+10  MULTIPOLYGON (((35.20958 36.67875, 35.20958 36...
# 1  Adiyaman  7.420537e+09  POLYGON ((38.68339 37.60323, 38.66182 37.59428...
# 2     Afyon  1.474743e+10  POLYGON ((30.18261 37.90116, 30.18878 37.89117...
# 3      Agri  1.030035e+10  POLYGON ((43.71635 39.37020, 43.70746 39.36575...
# 4   Aksaray  7.630818e+09  POLYGON ((34.39513 38.19467, 34.39626 38.18270...
# 5    Amasya  6.212560e+09  POLYGON ((35.22178 40.66905, 35.20362 40.66770...
# 6    Ankara  2.574928e+10  POLYGON ((33.74255 39.11185, 33.76644 39.10598...
# 7   Antalya  2.116656e+10  MULTIPOLYGON (((30.55347 36.46097, 30.55347 36...
# 8   Ardahan  4.786743e+09  POLYGON ((42.54808 40.64073, 42.53852 40.66104...
# 9    Artvin  7.769142e+09  POLYGON ((41.94059 40.74382, 41.93707 40.73332...
#
#    ToplamCocuk  ToplamKorucuyuAile
# 0          226                 166
# 1           44                  31
# 2          143                 118
# 3           12                   6
# 4           64                  46
# 5           57                  44
# 6          435                 381
# 7          182                 152
# 8            5                   3
# 9           12                   8

# %%
iller2.plot()

# %% [markdown]
# ## Gorsellestirme

# %%
ax = iller2.plot(figsize=(15,15))
ax.set_axis_off()

# %%
ax = iller2.plot(figsize=(15,15), column='ToplamCocuk')
ax.set_axis_off()

# %%
ax = iller2.plot(figsize=(15,15), column='ToplamCocuk', scheme='quantiles', legend=True)

# %%
import matplotlib as plt

ax = iller2.plot(figsize=(15,15), column='ToplamCocuk', scheme='fisher_jenks', legend=True)
ax.set_axis_off()
ax.set_title("Türkiye'deki Koruyucu Aile'deki Çocuk Sayısı")
plt.savefig('cikti/deneme_haritasi.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-173-e76949963e04> in <module>
#       4 ax.set_axis_off()
#       5 ax.set_title("Türkiye'deki Koruyucu Aile'deki Çocuk Sayısı")
# ----> 6 plt.savefig('cikti/deneme_haritasi.png')
#
# AttributeError: module 'matplotlib' has no attribute 'savefig'

# %%
iller2.to_file(r'cikti/iller2.shp')
